# %% [markdown]
# ## Goal: build our first image classifier and see if we can achieve world-class results

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *

# %%
# batch size (reduce this if you run out of memory!)
bs = 64

# %% [markdown]
# [Oxford-IIIT Pet Dataset](http://www.robots.ox.ac.uk/~vgg/data/pets/)
# [O. M. Parkhi et al., 2012](http://www.robots.ox.ac.uk/~vgg/publications/2012/parkhi12a/parkhi12a.pdf)

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.datasets:
#
# untar_data(url:str, fname:Union[pathlib.Path, str]=None, dest:Union[pathlib.Path, str]=None, data=True)
#     Download `url` if doesn't exist to `fname` and un-tgz to folder `dest`

# %%
doc(untar_data)
# Out:
# <h4 id="untar_data"><code>untar_data</code><a href="https://github.com/fastai/fastai/blob/master/fastai/datasets.py#L85" class="source_link">[source]</a></h4><blockquote><p><code>untar_data</code>(<code>url</code>:<code>str</code>, <code>fname</code>:<code>PathOrStr</code>=<code>None</code>, <code>dest</code>:<code>PathOrStr</code>=<code>None</code>, <code>data</code>=<code>True</code>)</p>
# </blockquote>
# <p>Download <code>url</code> if doesn't exist to <code>fname</code> and un-tgz to folder <code>dest</code></p>
# <p><a href="https://docs.fast.ai/datasets.html#untar_data" target="_blank" rel="noreferrer noopener">Show in docs</a></p>

# %%
path = untar_data(URLs.PETS)

# %%
print(path)
# Out:
# /root/.fastai/data/oxford-iiit-pet

# %%
path.ls()
# Out:
# ['annotations', 'images']

# %%
path_anno = path/'annotations'

# %%
path_anno
# Out:
# PosixPath('/root/.fastai/data/oxford-iiit-pet/annotations')

# %%
path_img = path/'images'

# %%
doc(get_image_files)
# Out:
# <h4 id="get_image_files"><code>get_image_files</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/data.py#L18" class="source_link">[source]</a></h4><blockquote><p><code>get_image_files</code>(<code>c</code>:<code>Path</code>, <code>check_ext</code>:<code>bool</code>=<code>True</code>) → <code>FilePathList</code></p>
# </blockquote>
# <p>Return list of files in <code>c</code> that are images. <code>check_ext</code> will filter to <code>image_extensions</code>.</p>
# <p><a href="https://docs.fast.ai/vision.data.html#get_image_files" target="_blank" rel="noreferrer noopener">Show in docs</a></p>

# %%
fnames = get_image_files(path_img, True)

# %%
fnames[:5]
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_175.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_174.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_202.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/chihuahua_118.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_193.jpg')]

# %%
len(fnames)
# Out:
# 7390

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'

# %%
doc(ImageDataBunch)
# Out:
# <h2 id="ImageDataBunch"><code>class</code> <code>ImageDataBunch</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/data.py#L258" class="source_link">[source]</a></h2><blockquote><p><code>ImageDataBunch</code>(<code>train_dl</code>:<a href="https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader"><code>DataLoader</code></a>, <code>valid_dl</code>:<a href="https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader"><code>DataLoader</code></a>, <code>test_dl</code>:<code>Optional</code>[<a href="https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader"><code>DataLoader</code></a>]=<code>None</code>, <code>device</code>:<a href="https://pytorch.org/docs/stable/tensor_attributes.html#torch-device"><code>device</code></a>=<code>None</code>, <code>tfms</code>:<code>Optional</code>[<code>Collection</code>[<code>Callable</code>]]=<code>None</code>, <code>path</code>:<code>PathOrStr</code>=<code>'.'</code>, <code>collate_fn</code>:<code>Callable</code>=<code>'data_collate'</code>) :: <a href="https://docs.fast.ai/basic_data.html#DataBunch"><code>DataBunch</code></a></p>
# </blockquote>
# <p>Bind <code>train_dl</code>,<code>valid_dl</code> and<code>test_dl</code> to <code>device</code>. tfms are DL tfms (normalize). <code>path</code> is for models.</p>
# <p><a href="https://docs.fast.ai/vision.data.html#ImageDataBunch" target="_blank" rel="noreferrer noopener">Show in docs</a></p>

# %%
doc(ImageDataBunch.from_name_re)
# Out:
# <h4 id="ImageDataBunch.from_name_re"><code>from_name_re</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/data.py#L329" class="source_link">[source]</a></h4><blockquote><p><code>from_name_re</code>(<code>path</code>:<code>PathOrStr</code>, <code>fnames</code>:<code>FilePathList</code>, <code>pat</code>:<code>str</code>, <code>valid_pct</code>:<code>int</code>=<code>0.2</code>, <code>test</code>:<code>str</code>=<code>None</code>, <code>kwargs</code>)</p>
# </blockquote>
# <p><a href="https://docs.fast.ai/vision.data.html#ImageDataBunch.from_name_re" target="_blank" rel="noreferrer noopener">Show in docs</a></p>

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs)

# %%
data.normalize(imagenet_stats)

# %%
data.show_batch(rows=4, figsize=(7,6))

# %% [markdown]
# ## Time to train our model

# %%
learn = ConvLearner(data, models.resnet34, metrics=error_rate, path="")

# %%
print(learn.model_dir)
print(URLs.LOCAL_PATH)
# Out:
# models
# /floyd/home/week-1

# %%
learn.save('foo')

# %%
learn.load('foo')

# %%
# Out:
# <h4 id="error_rate"><code>error_rate</code><a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L66" class="source_link">[source]</a></h4><blockquote><p><code>error_rate</code>(<code>input</code>:<code>Tensor</code>, <code>targs</code>:<code>Tensor</code>) → <code>Rank0Tensor</code></p>
# </blockquote>
# <p>1 - <a href="https://docs.fast.ai/metrics.html#accuracy"><code>accuracy</code></a></p>
# <p><a href="https://docs.fast.ai/metrics.html#error_rate" target="_blank" rel="noreferrer noopener">Show in docs</a></p>

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 05:41
# epoch  train_loss  valid_loss  error_rate
# 1      1.189739    0.334317    0.103792    (01:54)
# 2      0.506262    0.244845    0.076514    (01:16)
# 3      0.322667    0.215977    0.072522    (01:15)
# 4      0.229116    0.214749    0.071856    (01:15)

# %%
learn.save('stage-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15, 11))

# %%
doc(interp.plot_top_losses)
# Out:
# <h4 id="ClassificationInterpretation.plot_top_losses"><code>plot_top_losses</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/learner.py#L82" class="source_link">[source]</a></h4><blockquote><p><code>plot_top_losses</code>(<code>k</code>, <code>largest</code>=<code>True</code>, <code>figsize</code>=<code>(12, 12)</code>)</p>
# </blockquote>
# <p>Show images in <code>top_losses</code> along with their loss, label, and prediction.</p>
# <p><a href="https://docs.fast.ai/vision.learner.html#ClassificationInterpretation.plot_top_losses" target="_blank" rel="noreferrer noopener">Show in docs</a></p>

# %%
interp.plot_confusion_matrix(figsize=(12, 12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('staffordshire_bull_terrier', 'american_pit_bull_terrier', 6),
#  ('chihuahua', 'miniature_pinscher', 5),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 5),
#  ('boxer', 'american_bulldog', 5),
#  ('basset_hound', 'beagle', 4),
#  ('British_Shorthair', 'Russian_Blue', 4),
#  ('Egyptian_Mau', 'Bengal', 4),
#  ('Persian', 'Ragdoll', 4),
#  ('Ragdoll', 'Birman', 4),
#  ('Siamese', 'Birman', 3),
#  ('miniature_pinscher', 'chihuahua', 3)]

# %%
doc(learn.unfreeze)
# Out:
# <h4 id="Learner.unfreeze"><code>unfreeze</code><a href="https://github.com/fastai/fastai/blob/master/fastai/basic_train.py#L160" class="source_link">[source]</a></h4><blockquote><p><code>unfreeze</code>()</p>
# </blockquote>
# <p>Unfreeze entire model.</p>
# <p><a href="https://docs.fast.ai/basic_train.html#Learner.unfreeze" target="_blank" rel="noreferrer noopener">Show in docs</a></p>

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 01:20
# epoch  train_loss  valid_loss  error_rate
# 1      1.020643    0.553820    0.166999    (01:20)

# %%
learn.load('stage-1')

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-6, 1e-4))
# Out:
# Total time: 02:39
# epoch  train_loss  valid_loss  error_rate
# 1      0.212920    0.208923    0.070526    (01:20)
# 2      0.182488    0.200885    0.065203    (01:19)

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15, 11))

# %%
interp.most_confused(min_val=2)
# Out:
# [('chihuahua', 'miniature_pinscher', 5),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 5),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 5),
#  ('basset_hound', 'beagle', 4),
#  ('boxer', 'american_bulldog', 4),
#  ('miniature_pinscher', 'chihuahua', 4),
#  ('British_Shorthair', 'Russian_Blue', 3),
#  ('Ragdoll', 'Birman', 3),
#  ('Siamese', 'Birman', 3)]

# %% [markdown]
# ### Training with resnet50

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=320, bs=bs//2)
data.normalize(imagenet_stats)

# %%
bs//2
# Out:
# 32

# %%
bs/2
# Out:
# 32.0

# %%
learn = ConvLearner(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:49<00:00, 2085617.09it/s]

# %%
learn.fit_one_cycle(8, max_lr=slice(1e-3))
# Out:
# Total time: 27:55
# epoch  train_loss  valid_loss  error_rate
# 1      0.948864    0.345707    0.093606    (03:58)
# 2      0.424205    0.214025    0.068556    (03:24)
# 3      0.301492    0.193795    0.056691    (03:25)
# 4      0.233200    0.166880    0.057350    (03:25)
# 5      0.182799    0.158345    0.050099    (03:25)
# 6      0.138879    0.156368    0.053395    (03:25)
# 7      0.105651    0.151348    0.047462    (03:25)
# 8      0.088131    0.147666    0.047462    (03:25)

# %%
learn.save('stage-1-50')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2b26f0bd36a5> in <module>()
# ----> 1 print(learn)
#
# NameError: name 'learn' is not defined
